# %%
from provers import *

# %%
Po=["x<=x","x<=y & y<=x -> x=y","x<=y & y<=z -> x<=z"]
J=["(x v y)v z=x v(y v z)","x v y=y v x","x v x=x"]#,"x v y=y<->x<=y"]
M=["(x^y)^z=x^(y^z)","x^y=y^x","x^x=x"]#,"x^y=x<->x<=y"]
L=M+J+["x v(x^y)=x","x^(x v y)=x"]
D=L+["x^(y v z)=(x^y)v(x^z)"]
To=L+["x^y=x | x^y=y"] #["x<=y | y<=x"]
B=D+["x'v x=t","x'^x=b"]
Jii=["x<=y->x v z<=y v z","x<=y->z v x<=z v y"]
Mii=["x<=y->x^z<=y^z","x<=y->z^x<=z^y"]
Jia=["x<=y->x v z<=y v z","x<=y->z v y<=z v x"]
Mia=["x<=y->x^z<=y^z","x<=y->z^y<=z^x"]
Jaa=["x<=y->y v z<=x v z","x<=y->z v y<=z v x"]
Maa=["x<=y->y^z<=x^z","x<=y->z^y<=z^x"]

# %%
a=p9(L+Po,[],1000,1000,3)
# Out:
# Number of nonisomorphic models of cardinality 3  is  19
# === Mace4 starting on domain size 3. ===
#
# ------ process 61759 exit (all_models) ------

# %%
m4diag(a,"<=")
# Out:
# 1<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="77pt" height="19pt"
#  viewBox="0.00 0.00 77.00 19.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 15)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-15 73,-15 73,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-2.5" font-family="Times,serif" font-size="10.00" fill="#000000">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="#000000" cx="34.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-2.5" font-family="Times,serif" font-size="10.00" fill="#000000">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="#000000" cx="63.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="63.5" y="-2.5" font-family="Times,serif" font-size="10.00" fill="#000000">2</text>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 2<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="48pt" height="66pt"
#  viewBox="0.00 0.00 48.00 66.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 62)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-62 44,-62 44,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-49.5" font-family="Times,serif" font-size="10.00" fill="#000000">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="#000000" cx="34.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-2.5" font-family="Times,serif" font-size="10.00" fill="#000000">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="#000000" cx="34.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-49.5" font-family="Times,serif" font-size="10.00" fill="#000000">2</text>
# </g>
# <!-- 2&#45;&#45;1 -->
# <g id="edge1" class="edge">
# <title>2&#45;&#45;1</title>
# <path fill="none" stroke="#000000" d="M34.5,-46.7369C34.5,-37.6183 34.5,-19.9815 34.5,-11.0181"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 3<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="48pt" height="66pt"
#  viewBox="0.00 0.00 48.00 66.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 62)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-62 44,-62 44,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-49.5" font-family="Times,serif" font-size="10.00" fill="#000000">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="#000000" cx="34.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-49.5" font-family="Times,serif" font-size="10.00" fill="#000000">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="#000000" cx="34.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-2.5" font-family="Times,serif" font-size="10.00" fill="#000000">2</text>
# </g>
# <!-- 1&#45;&#45;2 -->
# <g id="edge1" class="edge">
# <title>1&#45;&#45;2</title>
# <path fill="none" stroke="#000000" d="M34.5,-46.7369C34.5,-37.6183 34.5,-19.9815 34.5,-11.0181"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 4<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="48pt" height="66pt"
#  viewBox="0.00 0.00 48.00 66.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 62)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-62 44,-62 44,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-2.5" font-family="Times,serif" font-size="10.00" fill="#000000">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="#000000" cx="34.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-49.5" font-family="Times,serif" font-size="10.00" fill="#000000">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="#000000" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-49.5" font-family="Times,serif" font-size="10.00" fill="#000000">2</text>
# </g>
# <!-- 2&#45;&#45;0 -->
# <g id="edge1" class="edge">
# <title>2&#45;&#45;0</title>
# <path fill="none" stroke="#000000" d="M5.5,-46.7369C5.5,-37.6183 5.5,-19.9815 5.5,-11.0181"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 5<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="48pt" height="66pt"
#  viewBox="0.00 0.00 48.00 66.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 62)">
# <title>%3</title>
# <polygon fill="#ffffff" stroke="transparent" points="-4,4 -4,-62 44,-62 44,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="#000000" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-2.5" font-family="Times,serif" font-size="10.00" fill="#000000">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="#000000" cx="34.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-2.5" font-family="Times,serif" font-size="10.00" fill="#000000">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="#000000" cx="19.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="19.5" y="-49.5" font-family="Times,serif" font-size="10.00" fill="#000000">2</text>
# </g>
# <!-- 2&#45;&#45;0 -->
# <g id="edge1" class="edge">
# <title>2&#45;&#45;0</title>
# <path fill="none" stroke="#000000" d="M17.894,-47.1085C15.1935,-38.0424 9.7752,-19.8524 7.0872,-10.8286"/>
# </g>
# <!-- 2&#45;&#45;1 -->
# <g id="edge2" class="edge">
# <title>2&#45;&#45;1</title>
# <path fill="none" stroke="#000000" d="M21.2207,-47.1085C24.1141,-38.0424 29.9195,-19.8524 32.7994,-10.8286"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 6<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.40.1 (20161225.0304)
#  -->
# <!-- Ti

# %%
m4diag(a,"<=")
# Out:
# 1<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="77pt" height="19pt"
#  viewBox="0.00 0.00 77.00 19.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 15)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-15 73,-15 73,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-3" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="34.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-3" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="63.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="63.5" y="-3" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 2<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="48pt" height="66pt"
#  viewBox="0.00 0.00 48.00 66.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 62)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-62 44,-62 44,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="34.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-3" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="34.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-50" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 2&#45;&#45;1 -->
# <g id="edge1" class="edge">
# <title>2&#45;&#45;1</title>
# <path fill="none" stroke="black" d="M34.5,-46.68C34.5,-37.98 34.5,-19.73 34.5,-11.15"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 3<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="48pt" height="66pt"
#  viewBox="0.00 0.00 48.00 66.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 62)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-62 44,-62 44,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="34.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-50" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="34.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-3" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 1&#45;&#45;2 -->
# <g id="edge1" class="edge">
# <title>1&#45;&#45;2</title>
# <path fill="none" stroke="black" d="M34.5,-46.68C34.5,-37.98 34.5,-19.73 34.5,-11.15"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 4<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="48pt" height="66pt"
#  viewBox="0.00 0.00 48.00 66.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 62)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-62 44,-62 44,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-3" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="34.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-50" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 2&#45;&#45;0 -->
# <g id="edge1" class="edge">
# <title>2&#45;&#45;0</title>
# <path fill="none" stroke="black" d="M5.5,-46.68C5.5,-37.98 5.5,-19.73 5.5,-11.15"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 5<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="48pt" height="66pt"
#  viewBox="0.00 0.00 48.00 66.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 62)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-62 44,-62 44,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-3" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="34.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="34.5" y="-3" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="19.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="19.5" y="-50" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 2&#45;&#45;0 -->
# <g id="edge1" class="edge">
# <title>2&#45;&#45;0</title>
# <path fill="none" stroke="black" d="M18.11,-47.02C15.42,-38.4 9.57,-19.57 6.89,-10.96"/>
# </g>
# <!-- 2&#45;&#45;1 -->
# <g id="edge2" class="edge">
# <title>2&#45;&#45;1</title>
# <path fill="none" stroke="black" d="M20.99,-47.02C23.87,-38.4 30.14,-19.57 33.01,-10.96"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 6<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="48pt" height="66pt"
#  viewBox="0.00 0.00 48.00 66.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 62)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-62 44,-62 44,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="blac

# %%
m4diag(a,"v")
# Out:
# 1<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="19pt" height="113pt"
#  viewBox="0.00 0.00 19.00 113.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 109)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-109 15,-109 15,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-3" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-99.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-97" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 1&#45;&#45;2 -->
# <g id="edge1" class="edge">
# <title>1&#45;&#45;2</title>
# <path fill="none" stroke="black" d="M5.5,-93.68C5.5,-84.98 5.5,-66.73 5.5,-58.15"/>
# </g>
# <!-- 2&#45;&#45;0 -->
# <g id="edge2" class="edge">
# <title>2&#45;&#45;0</title>
# <path fill="none" stroke="black" d="M5.5,-46.68C5.5,-37.98 5.5,-19.73 5.5,-11.15"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 2<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="19pt" height="113pt"
#  viewBox="0.00 0.00 19.00 113.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 109)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-109 15,-109 15,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-3" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-99.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-97" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 1&#45;&#45;2 -->
# <g id="edge1" class="edge">
# <title>1&#45;&#45;2</title>
# <path fill="none" stroke="black" d="M5.5,-93.68C5.5,-84.98 5.5,-66.73 5.5,-58.15"/>
# </g>
# <!-- 2&#45;&#45;0 -->
# <g id="edge2" class="edge">
# <title>2&#45;&#45;0</title>
# <path fill="none" stroke="black" d="M5.5,-46.68C5.5,-37.98 5.5,-19.73 5.5,-11.15"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 3<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="19pt" height="113pt"
#  viewBox="0.00 0.00 19.00 113.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 109)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-109 15,-109 15,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-3" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-99.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-97" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 1&#45;&#45;2 -->
# <g id="edge1" class="edge">
# <title>1&#45;&#45;2</title>
# <path fill="none" stroke="black" d="M5.5,-93.68C5.5,-84.98 5.5,-66.73 5.5,-58.15"/>
# </g>
# <!-- 2&#45;&#45;0 -->
# <g id="edge2" class="edge">
# <title>2&#45;&#45;0</title>
# <path fill="none" stroke="black" d="M5.5,-46.68C5.5,-37.98 5.5,-19.73 5.5,-11.15"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 4<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="19pt" height="113pt"
#  viewBox="0.00 0.00 19.00 113.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 109)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-109 15,-109 15,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-3" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-99.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-97" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 1&#45;&#45;2 -->
# <g id="edge1" class="edge">
# <title>1&#45;&#45;2</title>
# <path fill="none" stroke="black" d="M5.5,-93.68C5.5,-84.98 5.5,-66.73 5.5,-58.15"/>
# </g>
# <!-- 2&#45;&#45;0 -->
# <g id="edge2" class="edge">
# <title>2&#45;&#45;0</title>
# <path fill="none" stroke="black" d="M5.5,-46.68C5.5,-37.98 5.5,-19.73 5.5,-11.15"/>
# </g>
# </g>
# </svg>
# &nbsp; &nbsp; &nbsp;  &nbsp; 5<?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.43.0 (0)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="19pt" height="113pt"
#  viewBox="0.00 0.00 19.00 113.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 109)">
# <title>%3</title>
# <polygon fill="white" stroke="transparent" points="-4,4 -4,-109 15,-109 15,4 -4,4"/>
# <!-- 0 -->
# <g id="node1" class="node">
# <title>0</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-5.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-3" font-family="Times,serif" font-size="10.00">0</text>
# </g>
# <!-- 1 -->
# <g id="node2" class="node">
# <title>1</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-99.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-97" font-family="Times,serif" font-size="10.00">1</text>
# </g>
# <!-- 2 -->
# <g id="node3" class="node">
# <title>2</title>
# <ellipse fill="none" stroke="black" cx="5.5" cy="-52.5" rx="5.5" ry="5.5"/>
# <text text-anchor="middle" x="5.5" y="-50" font-family="Times,serif" font-size="10.00">2</text>
# </g>
# <!-- 1&#45;&#45;2 -->
# <g id="edge1" class="edge">
# <title>1&#45;&#45;2</title>
# <path fill="none" stroke="black" d="M5.5,-93.68C5.5,-84.98 5.5,-66.73 5.5,-58.15"/>
# </g>
# <!-- 2&#45;&#45;0 -->
# <g id=
